# %%
import sqlite3
import pandas as pd
import folium
from ipywidgets import interact, interactive, fixed, interact_manual,IntSlider
import ipywidgets as widgets

# %% [markdown]
# ### Constants

# %%
db_name = 'task.db'
table_name = 'cities'

# %% [markdown]
# ### Reading from database

# %%
connection = sqlite3.connect(f'{db_name}')
df = pd.read_sql_query(f'SELECT * FROM {table_name}', connection)
df.head()
# Out:
#    id              name  state_id state_code  country_id country_code  \
# 0   1  Andorra la Vella       488         07           6           AD
# 1   2           Arinsal       493         04           6           AD
# 2   3           Canillo       489         02           6           AD
# 3   4         El Tarter       489         02           6           AD
# 4   5            Encamp       487         03           6           AD
#
#    latitude  longitude           created_at           updated_at  flag  \
# 0  42.50779    1.52109  2019-10-05 23:58:06  2019-10-05 23:58:06     1
# 1  42.57205    1.48453  2019-10-05 23:58:06  2019-10-05 23:58:06     1
# 2  42.56760    1.59756  2019-10-05 23:58:06  2019-10-05 23:58:06     1
# 3  42.57952    1.65362  2019-10-05 23:58:06  2019-10-05 23:58:06     1
# 4  42.53474    1.58014  2019-10-05 23:58:06  2019-10-05 23:58:06     1
#
#   wikiDataId  store_latitude  store_longitude  store_distance
# 0      Q1863       39.107167         1.399403      378.271112
# 1     Q24554       48.106416         1.677519      615.578576
# 2     Q24554       44.695980         1.677438      236.752646
# 3     Q24413       37.469978         1.455186      568.406649
# 4     Q24413       48.064256         1.785558      615.064219

# %% [markdown]
# ### Map function

# %%
def create_map_by_city_name(city_name):
    filtered_df = df[df['name'] == cities.result]
    my_map = folium.Map(location = (filtered_df['latitude'].values[0], filtered_df['longitude'].values[0]), zoom_start = 13)
    folium.Marker(
            location=[filtered_df['latitude'].values[0], filtered_df['longitude'].values[0]],
            color='green',
            clustered_marker=True,
            popup='City',
            icon=folium.Icon(color='blue', icon='info-sign'),
        ).add_to(my_map)
    folium.Marker(
            location=[filtered_df['store_latitude'].values[0], filtered_df['store_longitude'].values[0]],
            color='green',
            clustered_marker=True,
            popup=f"Store, distance={filtered_df['store_distance'].values[0]:.2f} km.",
            icon=folium.Icon(color='green', icon='info-sign'),
        ).add_to(my_map)
    return my_map

# %% [markdown]
# ### Select city dropdown

# %%
cities = interactive(lambda cities: cities, cities=df['name']);
display(cities)
# Out:
# interactive(children=(Dropdown(description='cities', options=('Andorra la Vella', 'Arinsal', 'Canillo', 'El Ta…

# %%
selected_map = create_map_by_city_name(cities.result)
selected_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c590410d505704414aa20cae92acbb63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c590410d505704414aa20cae92acbb63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c590410d505704414aa20cae92acbb63 = L.map(
#                 &quot;map_c590410d505704414aa20cae92acbb63&quot;,
#                 {
#                     center: [49.65361111, 29.31333333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dff67efaa1185834ce955d84b2832519 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c590410d505704414aa20cae92acbb63);
#
#
#             var marker_41467f82b264de3ce8f50d46014886c2 = L.marker(
#                 [49.65361111, 29.31333333],
#                 {&quot;clusteredMarker&quot;: true, &quot;color&quot;: &quot;green&quot;}
#             ).addTo(map_c590410d505704414aa20cae92acbb63);
#
#
#             var icon_24215be7e9739832d89520faa8c1a130 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_41467f82b264de3ce8f50d46014886c2.setIcon(icon_24215be7e9739832d89520faa8c1a130);
#
#
#         var popup_c628ce17573451989f507258b3922bdf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0831ddf44c7a21dd013fd046518e34fa = $(`&lt;div id=&quot;html_0831ddf44c7a21dd013fd046518e34fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City&lt;/div&gt;`)[0];
#             popup_c628ce17573451989f507258b3922bdf.setContent(html_0831ddf44c7a21dd013fd046518e34fa);
#
#
#         marker_41467f82b264de3ce8f50d46014886c2.bindPopup(popup_c628ce17573451989f507258b3922bdf)
#         ;
#
#
#
#
#             var marker_8b02ce14d3381554d34d1a70f64c014a = L.marker(
#                 [47.1709305545, 27.8476666635],
#                 {&quot;clusteredMarker&quot;: true, &quot;color&quot;: &quot;green&quot;}
#             ).addTo(map_c590410d505704414aa20cae92acbb63);
#
#
#             var icon_76cadd0cb9977b90314d04dfb3cbf5f9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b02ce14d3381554d34d1a70f64c014a.setIcon(icon_76cadd0cb9977b90314d04dfb3cbf5f9);
#
#
#         var popup_4d69b5646b4e7490925a6d0ce31eff54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5d44af25729f53f7daa1a9ce5fcc9c8c = $(`&lt;div id=&quot;html_5d44af25729f53f7daa1a9ce5fcc9c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Store, distance=296.48 km.&lt;/div&gt;`)[0];
#             popup_4d69b5646b4e7490925a6d0ce31eff54.setContent(html_5d44af25729f53f7daa1a9ce5fcc9c8c);
#
#
#         marker_8b02ce14d3381554d34d1a70f64c014a.bindPopup(popup_4d69b5646b4e7490925a6d0ce31eff54)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
